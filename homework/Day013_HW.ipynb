# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)
soup = BeautifulSoup(r.text, "html5lib")
firstArticle = soup.find(class_="r-ent")
soup1 = BeautifulSoup(requests.get('https://www.ptt.cc'+soup.find(class_="title").find('a')['href']).text, "html5lib")
firstArticleObj = soup1.find_all('span',class_='article-meta-value')
#作者
print("作者；", firstArticleObj[0].text)
#標題
print("標題；",firstArticleObj[2].text)
#時間
print("時間；", firstArticleObj[3].text)
# Out:
# 作者； Ten6666 (德否魯曼)
# 標題； Re: [花邊] Jimmy Butler講當初會離開76人的原因
# 時間； Fri Mar 13 19:45:20 2020

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
#第一頁URL
url = 'https://www.ptt.cc/bbs/NBA/index1.html'
r = requests.get(url)
soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        ArticleObj = r.find_all('span',class_='article-meta-value')
        for a in ArticleObj:
            #作者
            print("作者；", ArticleObj[0].text)
            #標題
            print("標題；",ArticleObj[2].text)
            #時間
            print("時間；", ArticleObj[3].text)
    except:
        continue
# Out:
# [轉錄]Lyotard 對於太陽板討論串的結論
# 作者； Price (Price)
# 標題； [轉錄]Lyotard 對於太陽板討論串的結論
# 時間； Sun May 16 01:54:33 2004
# 作者； Price (Price)
# 標題； [轉錄]Lyotard 對於太陽板討論串的結論
# 時間； Sun May 16 01:54:33 2004
# 作者； Price (Price)
# 標題； [轉錄]Lyotard 對於太陽板討論串的結論
# 時間； Sun May 16 01:54:33 2004
# 作者； Price (Price)
# 標題； [轉錄]Lyotard 對於太陽板討論串的結論
# 時間； Sun May 16 01:54:33 2004
# [公告] 請停止一切關於本次活動的發言
# 作者； Price (Price)
# 標題； [公告] 請停止一切關於本次活動的發言
# 時間； Mon May 24 00:43:00 2004
# 作者； Price (Price)
# 標題； [公告] 請停止一切關於本次活動的發言
# 時間； Mon May 24 00:43:00 2004
# 作者； Price (Price)
# 標題； [公告] 請停止一切關於本次活動的發言
# 時間； Mon May 24 00:43:00 2004
# 作者； Price (Price)
# 標題； [公告] 請停止一切關於本次活動的發言
# 時間； Mon May 24 00:43:00 2004
# [轉錄]跟之前那篇比起來 我覺得這篇也應該轉過來
# 作者； Frankaze (神采風華)
# 標題； [轉錄]跟之前那篇比起來 我覺得這篇也應該轉過來
# 時間； Tue Jun  8 01:16:45 2004
# 作者； Frankaze (神采風華)
# 標題； [轉錄]跟之前那篇比起來 我覺得這篇也應該轉過來
# 時間； Tue Jun  8 01:16:45 2004
# 作者； Frankaze (神采風華)
# 標題； [轉錄]跟之前那篇比起來 我覺得這篇也應該轉過來
# 時間； Tue Jun  8 01:16:45 2004
# 作者； Frankaze (神采風華)
# ...

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
#第一頁URL
url = 'https://www.ptt.cc/bbs/Salary/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find(class_='article-meta-value').text)
    except:
        continue
# Out:
# [新聞] 時薪158元！台鐵徵84位「防疫天使」需有
# 作者: zzzz8931 (宅男)
# Re: [問題] 二月底離職 人資要我離職日填27號
# 作者: book2381 ()
# [閒聊] 工程師要領班對治具不好用負責？
# 作者: wendy150 (風)
# [問題] 可以應徵同公司不同部門的工作嗎
# 作者: chses (樹影)
# [公司] 請益源川國際 與 方圓國際
# 作者: ashleyc (Ashley)
# [公司] 有人聽過利隆科技投資公司嗎？
# [新聞] 中高齡者就業專法5月1日上路！續聘高齡勞工 雇主可拿獎金
# 作者: orz44444 (陰人本來就沒有當人的命~)
# [心得] 履歷怎麼寫？投了上百封CV後的反思
# 作者: astrid5636 (璟)
# (本文已被刪除) [romaziya]
# [閒聊] 有聽過泰商歐迪摩這家公司嗎
# 作者: smoltz1101 (人生勝利)
# Re: [選擇] offer選擇
# 作者: vaniaa (vaniaa)
# [問題] 剛到職就想走，是我太草莓還是工作太屎？
# 作者: abc292004 (罐子)
# Re: [心得] MBA畢業後年薪三百萬職涯分享
# 作者: KayRoe (資本主義右將軍)
# [選擇] 業助offer請益
# 作者: Alizcheng (艾黎斯)
# Re: [新聞] 遭長榮免職勞裁案敗訴　郭芷嫣：我不會放
# 作者: roxiang (天空之城)
# [討論] 有遇過新進員工比老員工薪水還很多很多的
# 作者: hebeshaman (Hebe)
# [公告] 關於板上免費服務與活動
# 作者: DDRMIX (約翰．史密斯)
# [公告] Salary板-新板規 2020/03/06
